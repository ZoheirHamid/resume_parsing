# %% [markdown]
# # Lab 2 Notebook
#
# ## Name: Zoheir Hamid
# ## Date: 9/10/2024
# This is the notebook for lab 2 assignment. I will upload a csv file using pandas and output a summary of that resume data set.

# %%
#import pandas library to work with dataframes

import pandas as pd
print("Library is ready to use")
# Out:
# Library is ready to use

# %%
#load csv file from my computer

resume_dataset = pd.read_csv(r"C:\Users\zohei\OneDrive\Documents\Data Wrangling\parsedResumes.csv")

#Take a look at the Dataset
resume_dataset.head(10)
# Out:
#        firstName    lastName        city         state      phnumber  \
# 0         Abiral      Pandey  Woonsocket  Rhode Island  940-242-3303
# 1        Adelina      Erimia         NaN       Georgia  496-331-7851
# 2       Mohammad     Tramboo         NaN           NaN  718-877-4291
# 3        Mounika    Surender         NaN           NaN  717-559-5134
# 4       Reddemma  Lankipalle   Norritown            PA    4846862294
# 5        Santosh       Kumar         NaN           NaN  484-999-0237
# 6  Jayadattaperi           N         NaN           NaN  469-629-8109
# 7        Madhuri         NaN         NaN           NaN  720-722-0838
# 8           Raja   Santhosam         NaN           NaN           NaN
# 9        Lorenzo     Zackery         NaN           NaN  215-980-1011
#
#                         email                         certifs  \
# 0   abiral.pandey88@gmail.com                             NaN
# 1              erimia@msn.com  PMP, Six Sigma Green Belt, SMC
# ...

# %%
college_graduates = resume_dataset.loc[(resume_dataset['education'] > 12)]
college_graduates
# Out:
#   firstName    lastName        city         state      phnumber  \
# 0    Abiral      Pandey  Woonsocket  Rhode Island  940-242-3303
# 1   Adelina      Erimia         NaN       Georgia  496-331-7851
# 2  Mohammad     Tramboo         NaN           NaN  718-877-4291
# 3   Mounika    Surender         NaN           NaN  717-559-5134
# 4  Reddemma  Lankipalle   Norritown            PA    4846862294
# 5   Santosh       Kumar         NaN           NaN  484-999-0237
# 8      Raja   Santhosam         NaN           NaN           NaN
#
#                         email                         certifs  \
# 0   abiral.pandey88@gmail.com                             NaN
# 1              erimia@msn.com  PMP, Six Sigma Green Belt, SMC
# 2    mfarhantramboo@gmail.com                  PSM, CSM, SCJP
# 3       smounika.ba@gmail.com                             NaN
# 4  reddemmaqa2_hr3@indeed.com                             NaN
# 5        kumar85aug@gmail.com                             NaN
# ...

# %%
resume_dataset.dtypes
# Out:
# firstName      object
# lastName       object
# city           object
# state          object
# phnumber       object
# email          object
# certifs        object
# skills         object
# salary        float64
# education     float64
# position       object
# experience      int64
# lastJob         int64
# pages           int64
# dtype: object

# %%
resume_dataset.describe()
# Out:
#        salary  education  experience    lastJob      pages
# count     0.0   7.000000    10.00000  10.000000  10.000000
# mean      NaN  16.571429     9.90000   1.600000   5.600000
# std       NaN   0.975900     3.17805   0.516398   1.776388
# min       NaN  16.000000     6.00000   1.000000   2.000000
# 25%       NaN  16.000000     8.00000   1.000000   6.000000
# 50%       NaN  16.000000     8.00000   2.000000   6.000000
# 75%       NaN  17.000000    12.50000   2.000000   6.000000
# max       NaN  18.000000    16.00000   2.000000   8.000000

# %%
resume_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   firstName   10 non-null     object
#  1   lastName    9 non-null      object
#  2   city        2 non-null      object
#  3   state       3 non-null      object
#  4   phnumber    9 non-null      object
#  5   email       9 non-null      object
#  6   certifs     4 non-null      object
#  7   skills      9 non-null      object
#  8   salary      0 non-null      float64
#  9   education   7 non-null      float64
#  10  position    10 non-null     object
#  11  experience  10 non-null     int64
#  12  lastJob     10 non-null     int64
#  13  pages       10 non-null     int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 1.2+ KB

# %%
resume_dataset.isna()
# Out:
#    firstName  lastName   city  state  phnumber  email  certifs  skills  \
# 0      False     False  False  False     False  False     True   False
# 1      False     False   True  False     False  False    False   False
# 2      False     False   True   True     False  False    False   False
# 3      False     False   True   True     False  False     True   False
# 4      False     False  False  False     False  False     True   False
# 5      False     False   True   True     False  False     True    True
# 6      False     False   True   True     False  False     True   False
# 7      False      True   True   True     False  False    False   False
# 8      False     False   True   True      True   True    False   False
# 9      False     False   True   True     False  False     True   False
#
#    salary  education  position  experience  lastJob  pages
# 0    True      False     False       False    False  False
# 1    True      False     False       False    False  False
# ...

# %%
resume_dataset.hist()
# Out:
# array([[<Axes: title={'center': 'salary'}>,
#         <Axes: title={'center': 'education'}>],
#        [<Axes: title={'center': 'experience'}>,
#         <Axes: title={'center': 'lastJob'}>],
#        [<Axes: title={'center': 'pages'}>, <Axes: >]], dtype=object)

# %%
# years of experience in comparison to education

resume_dataset.plot.scatter(x='experience', y='education')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # years of experience in comparison to education
# ----> 3 resume_dataset.plot.scatter(x='First Name', y='education')
#
# NameError: name 'resume_dataset' is not defined

# %%
# lenght of resume in comparison with experience

resume_dataset.plot.scatter(x='experience', y='pages')
# Out:
# <Axes: xlabel='experience', ylabel='pages'>
